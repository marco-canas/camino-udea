# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/camino-udea/blob/main/10_parciales/parcial_1_porcentaje_15/1_ejemplo_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display
from PIL import Image

def generar_qr(url, version=1, box_size=4, border=4, fill_color="black", back_color="white"):
    # Configurar el generador de QR
    qr = qrcode.QRCode(
        version=version,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=box_size,
        border=border,
    )
    
    # Añadir la URL al QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color=fill_color, back_color=back_color)
     
    return img

# %%
url_cuaderno_jupyter_parcial = "https://colab.research.google.com/github/marco-canas/camino-udea/blob/main/10_parciales/parcial_1_porcentaje_15/1_ejemplo_parcial.ipynb"
generar_qr(url_cuaderno_jupyter_parcial)

# %%
url_parcial_1 = "https://forms.gle/iRfcsCC6wtpShDnGA"
generar_qr(url_parcial_1)

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso Camino a La Universidad o PIVU:  ](https://github.com/marco-canas/camino-udea/blob/main/0_programa_curso_y_cronograma/programa_curso_pivu_caucasia.ipynb)

# %% [markdown]
# # Selección de Ejercicios de Lógica y Razonamiento
#
# ### 1. Estrategia del Peor Caso (Certeza Lógica)
# [cite_start]**Enunciado:** En un cajón hay 10 calcetines negros y 10 calcetines blancos[cite: 483]. [cite_start]Si sacas calcetines uno por uno sin mirar, ¿cuántos debes sacar para estar **seguro** de tener un par del mismo color? [cite: 484]
# * A. 2
# * [cite_start]B. 3 [cite: 486]
# * [cite_start]C. 11 [cite: 487]
# * [cite_start]D. 20 [cite: 488]
#
# ---

# %% [markdown]
# ### 2. Criptoaritmética (Resta con dígitos únicos)
# [cite_start]**Instrucciones:** En la resta figuran los dígitos del 0 al 9 una sola vez[cite: 576]. [cite_start]Hallar el valor de: **A + B - C** [cite: 576]
#
# | | | | |
# | :--- | :--- | :--- | :--- |
# | | **A** | **B** | 4 |
# | **-** | | 5 | 8 |
# | | 6 | **C** | 6 |
# [cite_start][cite: 577]
#
# ---

# %% [markdown]
# ### 3. Teoría de Conjuntos (Diagramas de Venn)
# [cite_start]**El Club de Deportes:** En un grupo de 80 deportistas, 35 practican natación, 40 practican atletismo y 12 practican ambos deportes[cite: 615, 616].
# * [cite_start]**Pregunta A:** ¿Cuántos practican solo atletismo? [cite: 617]
# * [cite_start]**Pregunta B:** ¿Cuántos no practican ninguno de los dos deportes? [cite: 618]
#
# ---

# %% [markdown]
# ### 4. Lógica de Predicados (Equivalencias)
# [cite_start]**Enunciado:** La frase "Es falso que algunos metales sean líquidos a temperatura ambiente" es equivalente a: [cite: 684]
# * (a) [cite_start]Todos los metales son líquidos[cite: 685].
# * (b) [cite_start]Ningún metal es líquido a temperatura ambiente[cite: 686].
# * (c) [cite_start]Al menos un metal es sólido[cite: 687].
# * (d) [cite_start]Algunos metales no son líquidos[cite: 688].
#
# ---

# %% [markdown]
# ### 5. Correspondencia Biunívoca (Tablas de Estados)
# **Nivel Inicial (3 Símbolos):** Símbolos: { ♠ , ♥ , ♦ } | [cite_start]Posiciones: {A, B, C} [cite: 748]
# * [cite_start]**Inicial:** [ ♠ , ♥ , ♦ ] — Contador: 0 [cite: 750]
# * [cite_start]**Jugada 1:** [ ♦ , ♥ , ♠ ] — Contador: 1 [cite: 751]
# * [cite_start]**Pregunta:** ¿Cuál es la correspondencia correcta para las posiciones A, B y C? [cite: 752]
#
# ---

# %% [markdown]
# ### 6. Distribución Numérica (Figuras Mágicas)
# [cite_start]**El Triángulo Mágico:** Coloca los números del **1 al 6** de modo que la suma de los tres números en cada lado del triángulo sea siempre **10**[cite: 850, 851].
#
# ```text
#           (  )
#          /    \
#       (  )    (  )
#       /          \
#    (  )---(  )---(  )
# ```
# [cite_start][cite: 853, 854, 855, 856, 857]
#
# ---

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Cálculo de Purcell](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES60UB4h-QFFqqRQUFmkpWcBIgoLBJeqTfZjNajWNWSeJA?e=9NxjKJ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=gaOjqk)
#
# * [McKinney, West. Python for data Analysis.](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=tfkShe)
