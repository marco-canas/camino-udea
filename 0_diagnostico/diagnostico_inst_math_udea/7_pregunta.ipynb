# %% [markdown]
# 7. La figura muestra una balanza de brazos iguales, la cual se encuentra en equilibrio cuando es cargada con pesas de magnitudes $A, B, C, X,$ y $Y$; en las cantidades indicadas.
#
# <img src="https://static-media.tercero.com.mx/2024/06/balanza.png" alt="Balanza" style="width: 300px;"/>
#
#
# De las situaciones siguientes, la única que no es posible es:
#
# a) $X = A$
# b) $X < B$
# c) $X > B$
# d) $X < A$ y $X < B$.

# %% [markdown]
# # Primera estrategia de razonamiento lógico para la solución de este problema: Razonamiento por disyunción de casoos o descarte.
#
# $$
# 2A + B + C = 3X + Y
# $$
